# %%
from transformers import T5Tokenizer
from diffusers import (
    CogVideoXPipeline,
    # CogVideoXTransformer3DModel,
    # AutoencoderKLCogVideoX,
)
from diffusers.video_processor import VideoProcessor
from diffusers.utils import export_to_video
import torch
from IPython.display import Video
# from diffusers.utils import export_to_gif
# from IPython.display import Image

# %%
# import torch
# from transformers import T5Tokenizer
# from diffusers import CogVideoXPipeline

def load_video_model_low_mem(model_path: str):
    # Load tokenizer
    try:
        tokenizer = T5Tokenizer.from_pretrained(
            model_path,
            subfolder="tokenizer",
            local_files_only=True
        )
        print("✅ Tokenizer loaded")
    except Exception:
        tokenizer = T5Tokenizer.from_pretrained(
            model_path,
            local_files_only=True
        )
        print("✅ Tokenizer loaded (fallback)")

    # Load pipeline with cuda
    pipe = CogVideoXPipeline.from_pretrained(
        model_path,
        torch_dtype=torch.float16,
        tokenizer=tokenizer,
        local_files_only=True,
        use_safetensors=True,
        device_map="cuda"  
    )
    print("✅ Pipeline loaded ")

    return pipe


# Usage
model_path = "../models/CogVideoX-5B"
pipe = load_video_model_low_mem(model_path)
# Out:
# ✅ Tokenizer loaded
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ✅ Pipeline loaded

# %%
# from diffusers.utils import export_to_video
# from diffusers.pipelines.cogvideo.pipeline_cogvideox import VideoProcessor


def generate_video(
    prompt,
    save_path,
    pipe,
    seconds=6,
    fps=6,
    steps=50,
    guidance=8.5,
    height=384,
    width=576,
    negative_prompt="blurry, deformed, low resolution, artifacts, distorted face"
):
    

    # Compute number of frames
    num_frames = seconds * fps
    if num_frames > 32:
        num_frames = 32  # safe fast limit

    print(f"Generating {num_frames} frames")

    # Run diffusion on GPU
    with torch.no_grad():
        out = pipe(
            prompt=prompt,
            num_frames=num_frames,
            height=height,
            width=width,
            num_inference_steps=steps,
            guidance_scale=guidance,
            output_type="latent",
            negative_prompt=negative_prompt
        )

    print("Decoding...")

    # Keep latents on GPU for faster decode
    latents = out.frames  # [B, F, C, H, W]

    # VAE info
    vae = pipe.vae
    vae_scale = vae.config.scaling_factor
    block_count = len(vae.config.block_out_channels)
    vae_scale_factor_spatial = 2 ** (block_count - 1)

    # Postprocessor
    video_processor = VideoProcessor(vae_scale_factor=vae_scale_factor_spatial)

    # Convert shape and unscale on GPU
    latents = latents.permute(0, 2, 1, 3, 4)   # B,C,F,H,W
    latents = latents / vae_scale

    # Decode on GPU if VAE is on GPU
    with torch.no_grad():
        decoded = vae.decode(latents).sample   # [-1,1]

    # Move to CPU only at the end
    decoded = decoded.to("cpu")

    # Final frames
    video = video_processor.postprocess_video(
        video=decoded, output_type="np"
    )[0]

    export_to_video(video, save_path, fps=fps)

    return save_path

# %%
prompt = """Spiderman in his red and blue suit fighting a powerful monkey on a city rooftop, dynamic action poses, fast movements, dramatic lighting, detailed textures, smooth cinematic motion, realistic environment, dust and wind effects, high energy battle scene, 4k quality, sharp focus, subtle camera shake, intense atmosphere
"""

generate_video(prompt,"videos/spider.mp4",pipe=pipe,guidance=10)
# Out:
# Generating 18 frames
#   0%|          | 0/50 [00:00<?, ?it/s]
# Decoding...
# 'videos/spider.mp4'

# %%
Video("videos/spider.mp4")
# Out:
# <video src="videos/spider.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
##Load Dataset
import pandas as pd
import os
DATASET_PATH='dataset/'
csv_path=DATASET_PATH+"dataset_with_prompt.csv"

df=pd.read_csv(inputfile)

if "video_path" not in df.columns:
        df["video_path"] = ""
    
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              150 non-null    int64
#  1   Title           150 non-null    object
#  2   Poet            150 non-null    object
#  3   text            150 non-null    object
#  4   ctext           150 non-null    object
#  5   Poem Link       150 non-null    object
#  6   our_summary     150 non-null    object
#  7   prompt_summary  150 non-null    object
#  8   video_path      7 non-null      object
# dtypes: int64(1), object(8)
# memory usage: 10.7+ KB
#    id                                          Title                 Poet  \
# 0   0  Dear John, Dear Coltrane by Michael S. Harper    Michael S. Harper
# 1   1                         Parrot by Stevie Smith         Stevie Smith
# 2   2                   Dust of Snow by Robert Frost         Robert Frost
# 3   3                Suburban Sonnet by Gwen Harwood         Gwen Harwood
# 4   4           Unending Love by Rabindranath Tagore  Rabindranath Tagore
#
#                                                 text  \
# 0  'Dear John, Dear Coltrane' by Michael S. Harpe...
# 1  ‘Parrot‘ depicts the declining health of a won...
# 2  The simplicity, in the end, is the key element...
# 3  'Suburban Sonnet' by Gwen Harwood is a poem ab...
# 4  'Unending Love' by Rabindranath Tagore is a he...
#
#                                                ctext  \
# 0  a love supreme, a love supreme\na love supreme...
# 1  The old sick green parrot\nHigh in a dingy cag...
# 2  The way a crow\nShook down on me\nThe dust of ...
# 3  She practises a fugue, though it can matter\nt...
# 4  I seem to have loved you in numberless forms, ...
#
#                                            Poem Link  \
# 0  https://www.poetryfoundation.org/poems/42827/d...
# 1  https://revise.wales/pastPapers/A-level/Englis...
# 2  https://www.poetryfoundation.org/poems/44262/d...
# 3  https://genius.com/Gwen-harwood-suburban-sonne...
# 4                https://allpoetry.com/Unending-Love
#
#                                          our_summary  \
# 0  The poem explores themes of love, loss, pain, ...
# 1  This old parrot, sick and full of rage, longs ...
# 2  The sight of a crow shaking snow from a tree t...
# 3  A mother practices music, but her children int...
# 4  The speaker expresses their eternal love for s...
#
#                                       prompt_summary    video_path
# 0  A lone musician stands on a dimly lit stage un...  videos/0.mp4
# 1  A weathered and aged parrot with vibrant yet m...  videos/1.mp4
# 2  A solitary poet, bundled in a woolen coat and ...  videos/2.mp4
# 3  A mother sits at a grand piano in a cozy livin...  videos/3.mp4
# 4  A person stands in a serene open field under a...  videos/4.mp4

# %%
prompt = df.iloc[1]["prompt_summary"]
print(prompt)
generate_video(prompt, "videos/2nd.mp4", pipe=pipe)
Video("videos/2nd.mp4")
# Out:
# An elderly parrot with vivid green feathers and a weathered beak sits on a windowsill in a small, dimly lit apartment. The bird's once vibrant plumage has dulled with age, and its eyes carry a deep sorrow. Outside the window, a distant view of a bustling urban landscape contrasts with the jungle he once called home. The parrot tilts its head slightly, its gaze fixed longingly on the far horizon, where lush greenery and exotic plants sway gently in the breeze. The room around it is sparse and cold, with muted tones and a faint glow of artificial light. The parrot’s claws grip the wooden sill tightly, its feathers slightly ruffled, as it appears to await the inevitable end, lost in a mix of sadness and yearning for its natural habitat.
# Generating 32 frames
#   0%|          | 0/50 [00:00<?, ?it/s]
# Decoding...
# <video src="videos/2nd.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
def process_dataset(df, pipe, video_dir: str = "videos", batch_size: int = 5):
    if "video_path" not in df.columns:
        df["video_path"] = ""

    pending = df[df["video_path"].isna() | (df["video_path"] == "")]
    if len(pending) == 0:
        print("All videos already generated.")
        return

    print(f"Pending videos: {len(pending)}")

    for start in range(0, len(pending), batch_size):
        end = start + batch_size
        batch = pending.iloc[start:end]

        print(f"\nProcessing batch {start} → {end}")

        for idx, row in batch.iterrows():
            poem_id = row["id"]
            prompt = row["prompt_summary"]
            save_path = os.path.join(video_dir, f"{poem_id}.mp4")

            print(f"{idx} ----------------------------------------------------")
            print(prompt)

            try:
                generate_video(prompt, save_path, pipe)
                df.loc[df["id"] == poem_id, "video_path"] = save_path
            except Exception as e:
                print(f"Error on {poem_id}: {e}")

            

        df.to_csv(csv_path, index=False)
        print("Batch saved.")

    print("Completed all videos.")

# %%
process_dataset(df,pipe)
# Out:
# Pending videos: 143
#
# Processing batch 0 → 5
# 7 ----------------------------------------------------
# A solitary figure stands by the edge of a quiet river surrounded by dense forest, their expression contemplative as they gaze out at the water. The sunlight filters through the trees, creating a serene yet melancholic atmosphere, reflecting their inner thoughts on mortality and the bittersweet nature of life. The figure then crouches by the riverbank, carefully catching a fish with their hands. As they hold it gently in their palms, they admire its shimmering scales, finding quiet beauty in its form. With a calm and deliberate motion, they prepare the fish for their meal, their face lit with a sense of resilience and appreciation for the simple act of survival. The scene captures the interplay between the solemnity of existence and the quiet strength of embracing life.
# Generating 32 frames
#   0%|          | 0/50 [00:00<?, ?it/s]
# Decoding...
# 8 ----------------------------------------------------
# A dynamic scene unfolds with a father and son practicing martial arts together in a serene dojo, their movements fluid and synchronized under the warm glow of hanging lanterns. The father, a middle-aged man with a calm demeanor and a neatly tied black belt, instructs the younger man, his son, who listens attentively, his youthful energy evident in his focused expressions. The atmosphere emphasizes their bond, captured through close-up shots of their hands clashing in sparring, their expressions one of mutual respect. In the second part of the scene, the son, now older and dressed in a plain white shirt, stands alone in a quiet garden, holding a piece of paper with handwritten poetry, his gaze distant, reflecting sorrow and remembrance of his father. The transition from joy to grief highlights the depth of their connection and the emotions following loss.
# Generating 32 frames
#   0%|          | 0/50 [00:00<?, ?it/s]
# Decoding...
# 9 ----------------------------------------------------
# A young woman sits on a wooden bench in a quiet park under the soft glow of a setting sun, her expression contemplative as she reads a journal. A breeze rustles the leaves of nearby trees, and a small child with a handful of colorful balloons runs past, adding a fleeting burst of energy to the serene scene. The woman's gaze shifts to the child’s playful laughter, her expression transitioning from introspective to quiet reflection. Moments later, the camera pans to her standing beside the child, smiling warmly as they share a moment of connection. The scene transitions to her walking along a winding path, leaving behind a trail of fallen autumn leaves, symbolizing growth and acceptance of life’s imperfections.
# Generating 32 frames
#   0%|          | 0/50 [00:00<?, ?it/s]
# Decoding...
# 10 ----------------------------------------------------
# A serene scene unfolds in a lush, sunlit meadow where a gentle breeze carries vibrant petals of various colors, creating a mesmerizing dance in the air. In the center, a young couple stands close, their expressions radiating warmth and tenderness as they exchange a heartfelt moment. Their love is symbolized by a glowing, ethereal light emanating from their clasped hands, casting a soft golden hue over the scene. Nearby, delicate wildflowers and soft ripples in a crystal-clear stream reflect the harmony of their bond. The surrounding forest sways gently in the breeze, evoking the cleansing and transformative power of love, while the couple gazes into each other’s eyes, cherishing their connection in the tranquil beauty of nature.
# Generating 32 frames
#   0%|          | 0/50 [00:00<?, ?it/s]
# Decoding...
# 11 ----------------------------------------------------
# A zoo during a sunny day, filled with lush greenery and vibrant flowers, where animals with glazed expressions lounge lazily in their enclosures. A group of children and adults wander around, seemingly unenthralled by the sight of a yawning lion resting under a tree and a couple of birds fluttering listlessly in a small aviary. Suddenly, the mood shifts as a sleek, fiery jaguar with vibrant orange and black markings gracefully prowls along the edge of its enclosure. Its piercing gaze locks onto the crowd, and it begins to pace powerfully, showcasing its muscular frame and sharp movements. The crowd captivated by the jaguar’s intensity, their expressions now filled with awe and excitement, while the other animals continue their relaxed demeanor, now overshadowed by the jaguar's commanding presence.
# Generating 32 frames
#   0%|          | 0/50 [00:00<?, ?it/s]
# Decoding...
# Batch saved.
#
# Processing batch 5 → 10
# 12 ----------------------------------------------------
# A large, majestic elephant with gray skin and long curved tusks stands in the middle of a bustling English village, surrounded by cobblestone streets, quaint cottages with thatched roofs, and curious onlookers. The elephant's expression shows a mix of confusion and curiosity as it gently touches a streetlamp with its trunk. The scene transitions to the elephant walking past a red double-decker bus and a street sign labeled "London," while a small child points at it in wonder. The next moment, the elephant is shown trekking through lush green fields under a golden sunset, the horizon revealing a vast expanse of the African savanna. As the elephant’s footsteps grow lighter and more confident, the scene transitions to it standing proudly among its herd in the vibrant landscape, with acacia trees and distant hills bathed in warm orange hues.
# Generating 32 frames
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 process_dataset(df,pipe)
#
# Cell In[26], line 27, in process_dataset(df, pipe, video_dir, batch_size)
#      24 print(prompt)
#      26 try:
# ---> 27     generate_video(prompt, save_path, pipe)
#      28     df.loc[df["id"] == poem_id, "video_path"] = save_path
#      29 except Exception as e:
#
# Cell In[3], line 28, in generate_video(prompt, save_path, pipe, seconds, fps, steps, guidance, height, width, negative_prompt)
#      26 # Run diffusion on GPU
#      27 with torch.no_grad():
# ---> 28     out = pipe(
#      29         prompt=prompt,
#      30         num_frames=num_frames,
#      31         height=height,
#      32         width=width,
#      33         num_inference_steps=steps,
#      34         guidance_scale=guidance,
#      35         output_type="latent",
#      36         negative_prompt=negative_prompt
#      37     )
#      39 print("Decoding...")
#      41 # Keep latents on GPU for faster decode
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/diffusers/pipelines/cogvideo/pipeline_cogvideox.py:743, in CogVideoXPipeline.__call__(self, prompt, negative_prompt, height, width, num_frames, num_inference_steps, timesteps, guidance_scale, use_dynamic_cfg, num_videos_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, output_type, return_dict, attention_kwargs, callback_on_step_end, callback_on_step_end_tensor_inputs, max_sequence_length)
#     741 # compute the previous noisy sample x_t -> x_t-1
#     742 if not isinstance(self.scheduler, CogVideoXDPMScheduler):
# --> 743     latents = self.scheduler.step(noise_pred, t, latents, **extra_step_kwargs, return_dict=False)[0]
#     744 else:
#     745     latents, old_pred_original_sample = self.scheduler.step(
#     746         noise_pred,
#     747         old_pred_original_sample,
#    (...)
#     752         return_dict=False,
#     753     )
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/diffusers/schedulers/scheduling_ddim_cogvideox.py:371, in CogVideoXDDIMScheduler.step(self, model_output, timestep, sample, eta, use_clipped_model_output, generator, variance_noise, return_dict)
#     368 alpha_prod_t = self.alphas_cumprod[timestep]
#     369 alpha_prod_t_prev = self.alphas_cumprod[prev_timestep] if prev_timestep >= 0 else self.final_alpha_cumprod
# --> 371 beta_prod_t = 1 - alpha_prod_t
#     373 # 3. compute predicted original sample from predicted noise also called
#     374 # "predicted x_0" of formula (12) from https://huggingface.co/papers/2010.02502
#     375 # To make style tests pass, commented out `pred_epsilon` as it is an unused variable
#     376 if self.config.prediction_type == "epsilon":
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/torch/_tensor.py:43, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(self, *args, **kwargs)
#      40 try:
#      41     # See https://github.com/pytorch/pytorch/issues/75462
#      42     sargs = self, *args
# ---> 43     if has_torch_function(sargs):
#      44         return handle_torch_function(wrapped, sargs, *sargs, **kwargs)
#      45     return f(self, *args, **kwargs)
#
# KeyboardInterrupt:

# %%
from IPython.display import Video, display

for _, row in df.iterrows():
    poem_id = row["id"]
    prompt = row["prompt_summary"]
    path = row["video_path"]

    if pd.isna(path) or path == "":
        break

    print(f"{poem_id} ----------------------------------------------------")
    print(prompt)
    print(path)

    # display(Video(path))
# Out:
# 0 ----------------------------------------------------
