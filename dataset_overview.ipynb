# %%
import pandas as pd
import sys
print(sys.version)
print("pandas version" , pd.__version__)
# Out:
# 3.10.19 (main, Oct 21 2025, 16:43:05) [GCC 11.2.0]
# pandas version 2.3.3

# %%
##import dataset
DATASET_PATH='dataset/'
df=pd.read_csv(DATASET_PATH+"dataset_with_prompt.csv")
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              150 non-null    int64
#  1   Title           150 non-null    object
#  2   Poet            150 non-null    object
#  3   text            150 non-null    object
#  4   ctext           150 non-null    object
#  5   Poem Link       150 non-null    object
#  6   our_summary     150 non-null    object
#  7   prompt_summary  150 non-null    object
#  8   video_path      12 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 10.7+ KB
# (150, 9)

# %%
df.head()
# Out:
#    id                                          Title                 Poet  \
# 0   0  Dear John, Dear Coltrane by Michael S. Harper    Michael S. Harper
# 1   1                         Parrot by Stevie Smith         Stevie Smith
# 2   2                   Dust of Snow by Robert Frost         Robert Frost
# 3   3                Suburban Sonnet by Gwen Harwood         Gwen Harwood
# 4   4           Unending Love by Rabindranath Tagore  Rabindranath Tagore
#
#                                                 text  \
# 0  'Dear John, Dear Coltrane' by Michael S. Harpe...
# 1  ‘Parrot‘ depicts the declining health of a won...
# 2  The simplicity, in the end, is the key element...
# 3  'Suburban Sonnet' by Gwen Harwood is a poem ab...
# 4  'Unending Love' by Rabindranath Tagore is a he...
#
#                                                ctext  \
# 0  a love supreme, a love supreme\na love supreme...
# 1  The old sick green parrot\nHigh in a dingy cag...
# ...

# %%
ndf=df[['text','ctext','our_summary']]
ndf.head()
# Out:
#                                                 text  \
# 0  'Dear John, Dear Coltrane' by Michael S. Harpe...
# 1  ‘Parrot‘ depicts the declining health of a won...
# 2  The simplicity, in the end, is the key element...
# 3  'Suburban Sonnet' by Gwen Harwood is a poem ab...
# 4  'Unending Love' by Rabindranath Tagore is a he...
#
#                                                ctext  \
# 0  a love supreme, a love supreme\na love supreme...
# 1  The old sick green parrot\nHigh in a dingy cag...
# 2  The way a crow\nShook down on me\nThe dust of ...
# 3  She practises a fugue, though it can matter\nt...
# 4  I seem to have loved you in numberless forms, ...
#
#                                          our_summary
# 0  The poem explores themes of love, loss, pain, ...
# 1  This old parrot, sick and full of rage, longs ...
# 2  The sight of a crow shaking snow from a tree t...
# 3  A mother practices music, but her children int...
# 4  The speaker expresses their eternal love for s...

# %%
row_num=9
for c in ['Title','ctext','text','our_summary']:
    print(c)
    print(df.loc[row_num,c])
    print("-"*90)
# Out:
# Title
# Babies by Alice Fulton
# ------------------------------------------------------------------------------------------
# ctext
# born gorgeous with nerves, with brains
# the pink of silver polish or
# jellyfish wafting ornately
# through the body below.
# An invertebrate cooing
# on the mother
# tongue shushes and lulls them into thinking
# all is well. As they grow they learn
#
# salvage: tear-out
# guides to happiness say apologies can outshine
# lies, guilt be lickspittled from their lives, bad
# glycerined to good. Like a child’s first school pencils
# in their formal brilliance
# and sharp new smells, they lie
#
# as lovers. Maybe one cries
# the wrong name and the night skinning
# them pleasantly alive
# leaps away in shards.
# Then it’s time for restitution:
# a tin of homebaked,
# holding gingham safety, fetal
# as the light through mason jars of beets and brine,
# or jewelry, clasping and unclasping
# aisles of fluorescence from great department stores,
# ...
